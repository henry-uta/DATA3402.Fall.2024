# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, count, maximum_value):
        self.count = count
        self.maximum_value = maximum_value

    def increment(self):
        if(self.count >= self.maximum_value):
            print("Error: Maximum Value Reached")
        else:
            self.count += 1

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, count, maximum_value):
        self.__count = count
        self.__maximum_value = maximum_value

    def increment(self):
        if(self.__count >= self.__maximum_value):
            print("Error: Maximum Value Reached")
        else:
            self.__count += 1

    def get_count(self):
        return self.__count

    def get_maximum(self):
        return self.__maximum_value

    def check_maximum(self):
        return self.__count >= self.maximum_value

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self,length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * self.__length + 2 * self.__width

    def get_length(self):
        return self.__length
        
    def get_width(self):
        return self.__width
        
    def get_coordinates(self):
        return (self.__x, self.__y)

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self, radius,x,y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return 3.1415 * self.__radius ** 2

    def perimeter(self):
        return 2 * 3.1415 * self.__radius

    def get_radius(self):
        return self.__radius
        
    def get_coordinates(self):
        return (self.__x, self.__y)

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class shape:
    __name = ""
    def __init__(self, name):
        self.__name = name

    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def get_coordinates(self):
        raise NotImplementedError

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__("Rectangle")
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * self.__length + 2 * self.__width

    def get_coordinates(self):
        return (self.__x, self.__y)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__("Circle")
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return 3.1415 * self.__radius ** 2

    def perimeter(self):
        return 2 * 3.1415 * self.__radius

    def get_coordinates(self):
        return (self.__x, self.__y)

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, name, x1, y1, x2, y2, x3, y3):
        super().__init__(name)
        self.__x1, self.__y1 = x1, y1
        self.__x2, self.__y2 = x2, y2
        self.__x3, self.__y3 = x3, y3

    def area(self):
        return abs((self.__x1*(self.__y2 - self.__y3) + self.__x2*(self.__y3 - self.__y1) + self.__x3*(self.__y1 - self.__y2)) / 2.0)

    def perimeter(self):
        side1 = ((self.__x2 - self.__x1)**2 + (self.__y2 - self.__y1)**2)**0.5
        side2 = ((self.__x3 - self.__x2)**2 + (self.__y3 - self.__y2)**2)**0.5
        side3 = ((self.__x3 - self.__x1)**2 + (self.__y3 - self.__y1)**2)**0.5
        return side1 + side2 + side3

    def get_coordinates(self):
        return [(self.__x1, self.__y1), (self.__x2, self.__y2), (self.__x3, self.__y3)]

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    __name = ""
    
    def __init__(self, name):
        self.__name = name

    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_coordinates(self):
        raise NotImplementedError

    def get_parameter_points(self):
        raise NotImplementedError

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__("Rectangle")
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * self.__length + 2 * self.__width

    def get_coordinates(self):
        return (self.__x, self.__y)

    def get_parameter_points(self):
        points = []

        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__length, self.__y
        x3, y3 = self.__x + self.__length, self.__y + self.__width
        x4, y4 = self.__x, self.__y + self.__width

        for t in range(5):

            points.append((x1 + t * (x2 - x1) / 4, y1))
            points.append((x2, y2 + t * (y3 - y2) / 4))
            points.append((x3 - t * (x3 - x4) / 4, y3))
            points.append((x4, y4 - t * (y4 - y1) / 4))
        return points[:16]

import math

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__("Circle")
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_coordinates(self):
        return (self.__x, self.__y)

    def get_parameter_points(self):
        points = []
        for angle in range(0, 360, 22):
            radians = math.radians(angle)
            x = self.__x + self.__radius * math.cos(radians)
            y = self.__y + self.__radius * math.sin(radians)
            points.append((x, y))
        return points
        
class Triangle(Shape):
    def __init__(self, name, x1, y1, x2, y2, x3, y3):
        super().__init__(name)
        self.__x1, self.__y1 = x1, y1
        self.__x2, self.__y2 = x2, y2
        self.__x3, self.__y3 = x3, y3

    def area(self):
        return abs((self.__x1*(self.__y2 - self.__y3) + self.__x2*(self.__y3 - self.__y1) + self.__x3*(self.__y1 - self.__y2)) / 2.0)

    def perimeter(self):
        side1 = ((self.__x2 - self.__x1)**2 + (self.__y2 - self.__y1)**2)**0.5
        side2 = ((self.__x3 - self.__x2)**2 + (self.__y3 - self.__y2)**2)**0.5
        side3 = ((self.__x3 - self.__x1)**2 + (self.__y3 - self.__y1)**2)**0.5
        return side1 + side2 + side3

    def get_coordinates(self):
        return [(self.__x1, self.__y1), (self.__x2, self.__y2), (self.__x3, self.__y3)]

    def get_parameter_points(self):
        points = self.get_coordinates()
        all_points = []
        
        for i in range(3):
            x1, y1 = points[i]
            x2, y2 = points[(i + 1) % 3]
            for t in range(5):  
                xt = x1 + t * (x2 - x1) / 4.0
                yt = y1 + t * (y2 - y1) / 4.0
                all_points.append((xt, yt))

        return all_points[:16]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    __name = ""
    
    def __init__(self, name):
        self.__name = name

    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_coordinates(self):
        raise NotImplementedError

    def get_parameter_points(self):
        raise NotImplementedError

    def is_inside(self, x, y):
        raise NotImplementedError

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__("Rectangle")
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * self.__length + 2 * self.__width

    def get_coordinates(self):

        return (self.__x, self.__y)

    def get_parameter_points(self):

        points = []

        x1, y1 = self.__x, self.__y
        x2, y2 = self.__x + self.__length, self.__y
        x3, y3 = self.__x + self.__length, self.__y + self.__width
        x4, y4 = self.__x, self.__y + self.__width

        for t in range(5):

            points.append((x1 + t * (x2 - x1) / 4, y1))
            points.append((x2, y2 + t * (y3 - y2) / 4))
            points.append((x3 - t * (x3 - x4) / 4, y3))
            points.append((x4, y4 - t * (y4 - y1) / 4))

        return points[:16] 

    def is_inside(self, x, y):
    
        return self.__x <= x <= (self.__x + self.__length) and self.__y <= y <= (self.__y + self.__width)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__("Circle")
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_coordinates(self):
        return (self.__x, self.__y)

    def get_parameter_points(self):
        points = []
        for angle in range(0, 360, 22):
            radians = math.radians(angle)
            x = self.__x + self.__radius * math.cos(radians)
            y = self.__y + self.__radius * math.sin(radians)
            points.append((x, y))
        return points

    def is_inside(self, x, y):
        distance = math.sqrt((x - self.__x) ** 2 + (y - self.__y) ** 2)
        return distance <= self.__radiu

class Triangle(Shape):
    def __init__(self, name, x1, y1, x2, y2, x3, y3):
        super().__init__(name)
        self.__x1, self.__y1 = x1, y1
        self.__x2, self.__y2 = x2, y2
        self.__x3, self.__y3 = x3, y3

    def area(self):
        return abs((self.__x1 * (self.__y2 - self.__y3) + self.__x2 * (self.__y3 - self.__y1) + self.__x3 * (self.__y1 - self.__y2)) / 2.0)

    def perimeter(self):
        side1 = math.sqrt((self.__x2 - self.__x1) ** 2 + (self.__y2 - self.__y1) ** 2)
        side2 = math.sqrt((self.__x3 - self.__x2) ** 2 + (self.__y3 - self.__y2) ** 2)
        side3 = math.sqrt((self.__x3 - self.__x1) ** 2 + (self.__y3 - self.__y1) ** 2)
        return side1 + side2 + side3

    def get_coordinates(self):
        return [(self.__x1, self.__y1), (self.__x2, self.__y2), (self.__x3, self.__y3)]

    def is_inside(self, x, y):
        area_full = self.area()

        area1 = abs((x * (self.__y2 - self.__y3) + self.__x2 * (self.__y3 - y) + self.__x3 * (y - self.__y2)) / 2.0)
        area2 = abs((self.__x1 * (y - self.__y3) + x * (self.__y3 - self.__y1) + self.__x3 * (self.__y1 - y)) / 2.0)
        area3 = abs((self.__x1 * (self.__y2 - y) + self.__x2 * (y - self.__y1) + x * (self.__y1 - self.__y2)) / 2.0)

        return abs((area1 + area2 + area3) - area_full) < 1e-6

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    __name = ""
    
    def __init__(self, name):
        self.__name = name

    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_coordinates(self):
        raise NotImplementedError

    def get_parameter_points(self):
        raise NotImplementedError

    def is_inside(self, x, y):
        raise NotImplementedError

    def overlaps(self, other):
        raise NotImplementedError

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
import math

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

class Shape:
    def __init__(self, name):
        self.__name = name

    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_coordinates(self):
        raise NotImplementedError

    def overlaps(self, other):
        raise NotImplementedError

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__("Rectangle")
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_coordinates(self):
        return (self.__x, self.__y)

    def draw(self, canvas, char='*'):
        for i in range(self.__width):
            canvas.set_pixel(self.__y, self.__x + i, char=char) 
            canvas.set_pixel(self.__y + self.__length - 1, self.__x + i, char=char)  
        for i in range(self.__length):
            canvas.set_pixel(self.__y + i, self.__x, char=char) 
            canvas.set_pixel(self.__y + i, self.__x + self.__width - 1, char=char)

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__("Circle")
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_coordinates(self):
        return (self.__x, self.__y)


    def draw(self, canvas, char='*'):
        for angle in range(0, 360, 10):
            rad = math.radians(angle)
            x = int(self.__x + self.__radius * math.cos(rad))
            y = int(self.__y + self.__radius * math.sin(rad))
            canvas.set_pixel(y, x, char=char)
            
class Triangle(Shape):
    def __init__(self, name, x1, y1, x2, y2, x3, y3):
        super().__init__(name)
        self.__x1, self.__y1 = x1, y1
        self.__x2, self.__y2 = x2, y2
        self.__x3, self.__y3 = x3, y3

    def area(self):
        return abs((self.__x1 * (self.__y2 - self.__y3) + self.__x2 * (self.__y3 - self.__y1) + self.__x3 * (self.__y1 - self.__y2)) / 2.0)

    def perimeter(self):
        pass

    def get_coordinates(self):
        return [(self.__x1, self.__y1), (self.__x2, self.__y2), (self.__x3, self.__y3)]

    def draw(self, canvas, char='*'):
        max_width = canvas.width - 1
        max_height = canvas.height - 1

        x1, y1 = max(0, min(self.__x1, max_width)), max(0, min(self.__y1, max_height))
        x2, y2 = max(0, min(self.__x2, max_width)), max(0, min(self.__y2, max_height))
        x3, y3 = max(0, min(self.__x3, max_width)), max(0, min(self.__y3, max_height))

        self.safe_line(canvas, x1, y1, x2, y2, char)
        self.safe_line(canvas, x2, y2, x3, y3, char)
        self.safe_line(canvas, x3, y3, x1, y1, char)

    def safe_line(self, canvas, x1, y1, x2, y2, char):
 
        try:
            canvas.line(x1, y1, x2, y2, char=char)
        except IndexError:

            pass

class CompoundShape(Shape):
    def __init__(self, name):
        super().__init__(name)
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def draw(self, canvas, char='*'):
        for shape in self.shapes:
            shape.draw(canvas, char)

if __name__ == "__main__":
    canvas = Canvas(50, 20)

    circle = Circle(5, 10, 10)
    rectangle = Rectangle(5, 10, 20, 5)
    triangle = Triangle("Triangle", 30, 5, 40, 5, 35, 15)

    circle.draw(canvas, char='o')
    rectangle.draw(canvas, char='#')
    triangle.draw(canvas, char='*')

    compound = CompoundShape("CompoundShape")
    compound.add_shape(circle)
    compound.add_shape(rectangle)
    compound.add_shape(triangle)

    canvas.clear_canvas()
    compound.draw(canvas, char='+')

    canvas.display()
# Out:
#           +
#
#          +
#
#         +
#        ++++++       ++++++++++
#       ++     +      +        +
#      +        +     +        +
#      ++       +     +        +
#      +        +     ++++++++++
#      +        ++
#      +        +
#      +        +
#       +      +
#        ++++++
#           +

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
